# %%
from newspaper import Article

url = 'https://www.nytimes.com/2010/04/13/opinion/13wenzel.html'

# %%
article = Article(url)
article.download()
article.parse()
article.nlp()
print(article.keywords)
print(article.summary)
# Out:
# ['control', 'virus', 'public', 'children', 'learned', 'health', 'work', 'vaccination', 'schools', 'h1n1s', 'opinion', 'need', 'authorities']
# Public health groups emphasized the necessity of frequent hand-washing, which surely helped reduce transmission.
# In our own country, the virus struck at a time when Americans seemed particularly skeptical about our government and large institutions.
# It is not an easy task, but our public health authorities need to become clearer about the lexicon of uncertainty  what they know and don’t know about a pandemic.
# Even as we work to solve these enigmas, we can try to prepare better for future pandemics.
# First, we need to approach disease control not as individual nations, but as a global community.

# %%
article.publish_date
# Out:
# datetime.datetime(2010, 4, 13, 0, 0)

# %%
from nytimesarticle import articleAPI
api = articleAPI('GiEgG2mBQSbTKKIBkrZVb1oDv9ru7HAw')
articles = api.search( q = 'H1N1', )

# %%
articles = api.search( q = 'H1N1', )

# %%
articles["response"]["docs"]
# Out:
# [{'abstract': 'For all the anxiety surrounding the spread of swine flu, some of the most effective flu countermeasures are also the cheapest and simplest: social distancing (keeping about three feet away from potentially infected people) and washing your hands.',
#   'web_url': 'https://freakonomics.blogs.nytimes.com/2009/09/03/blogs/03freakonomics-hhss-diy17683.html',
#   'snippet': 'For all the anxiety surrounding the spread of swine flu, some of the most effective flu countermeasures are also the cheapest and simplest: social distancing (keeping about three feet away from potentially infected people) and washing your hands.',
#   'lead_paragraph': 'For all the anxiety surrounding the spread of swine flu, some of the most effective flu countermeasures are also the cheapest and simplest: social distancing (keeping about three feet away from potentially infected people) and washing your hands. The trick is getting people to take the advice. So the Obama administration held an open contest for the public to create the most compelling anti-flu public service announcement. Watch and vote on the finalists, here. Unlike earlier anti-flu campaigns, which tried to scare the public into readiness, these home-made ads are lighthearted and aim to empower. Which is more effective?',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': "HHS's DIY H1N1 PSA",
#    'kicker': 'Freakonomics',
#    'content_kicker': None,
#    'print_headline': 'HHS&#39;s DIY H1N1 PSA',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2009-09-03T13:44:40+0000',
#   'document_type': 'article',
#   'news_desk': 'None',
#   'section_name': 'Blogs',
#   'byline': {'original': 'By FREAKONOMICS',
#    'person': [{'firstname': 'Freakonomics',
#      'middlename': None,
#      'lastname': None,
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Web Log',
#   '_id': 'nyt://article/7407f77f-dad7-5387-8b77-c5b2b97e5067',
#   'word_count': 99,
#   'uri': 'nyt://article/7407f77f-dad7-5387-8b77-c5b2b97e5067'},
#  {'abstract': 'Health care workers in Indiana and Tennessee were among the first people to receive H1N1 flu vaccine in the United States.',
#   'web_url': 'https://www.nytimes.com/video/multimedia/1247465007327/health-workers-get-h1n1-vaccine.html',
#   'snippet': 'Health care workers in Indiana and Tennessee were among the first people to receive H1N1 flu vaccine in the United States.',
#   'lead_paragraph': 'Health care workers in Indiana and Tennessee were among the first people to receive H1N1 flu vaccine in the United States.',
#   'source': 'Reuters',
#   'multimedia': [{'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/05/multimedia/2009-10-05T222808Z_1_LOVE5941QEVRX_RTRMADP_THUMBNAIL-90X67_USA-H1N1-VACCINE.JPG',
#     'height': 67,
#     'width': 90,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/05/multimedia/2009-10-05T222808Z_1_LOVE5941QEVRX_RTRMADP_3_USA-H1N1-VACCINE.JPG',
#     'height': 480,
#     'width': 640,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/06/multimedia/2009-10-05T222808Z_1_LOVE5941QEVRX_RTRMADP_1_USA-H1N1-VACCINE.JPG',
#     'height': 112,
#     'width': 150,
#     'legacy': {'thumbnail': 'images/2009/10/06/multimedia/2009-10-05T222808Z_1_LOVE5941QEVRX_RTRMADP_1_USA-H1N1-VACCINE.JPG',
#      'thumbnailwidth': 150,
#      'thumbnailheight': 112},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'}],
#   'headline': {'main': 'Health Workers Get H1N1 Vaccine',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2009-10-06T05:16:45+0000',
#   'document_type': 'multimedia',
#   'news_desk': '',
#   'section_name': 'Multimedia/Photos',
#   'byline': {'original': 'Reuters', 'person': [], 'organization': 'Reuters'},
#   'type_of_material': 'Video',
#   '_id': 'nyt://video/fb4982b3-7556-5102-865b-c4da4792eb67',
#   'word_count': 0,
#   'uri': 'nyt://video/fb4982b3-7556-5102-865b-c4da4792eb67'},
#  {'abstract': 'Schools are a perfect environment for a virus to spread, so every county should make a concerted effort to monitor and minimize outbreaks.',
#   'web_url': 'https://www.nytimes.com/2009/08/02/opinion/02king.html',
#   'snippet': 'Schools are a perfect environment for a virus to spread, so every county should make a concerted effort to monitor and minimize outbreaks.',
#   'lead_paragraph': 'Baltimore',
#   'print_section': 'WK',
#   'print_page': '10',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/08/02/opinion/kingWT.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2009/08/02/opinion/kingWT.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/08/02/opinion/kingXL.jpg',
#     'height': 450,
#     'width': 450,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/08/02/opinion/king190.jpg',
#     'height': 260,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/08/02/opinion/king75.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2009/08/02/opinion/king75.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'}],
#   'headline': {'main': 'The ABC’s of H1N1',
#    'kicker': 'Op-Ed Contributor',
#    'content_kicker': None,
#    'print_headline': 'The ABC’s of H1N1',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Education and Schools',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Children and Youth', 'rank': 2, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Centers for Disease Control and Prevention',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Swine Influenza', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2009-08-01T23:49:54+0000',
#   'document_type': 'article',
#   'news_desk': 'OpEd',
#   'section_name': 'Opinion',
#   'byline': {'original': 'By James C. King Jr',
#    'person': [{'firstname': 'James',
#      'middlename': 'C.',
#      'lastname': 'King',
#      'qualifier': 'Jr',
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Op-Ed',
#   '_id': 'nyt://article/9a917418-5e1c-52e6-8a75-93bcbc846b15',
#   'word_count': 529,
#   'uri': 'nyt://article/9a917418-5e1c-52e6-8a75-93bcbc846b15'},
#  {'abstract': 'A debate over the connection between large-scale concentrated animal feeding operations and the spread of the H1N1 virus is spilling into the mainstream.',
#   'web_url': 'https://green.blogs.nytimes.com/2009/11/09/debate-modern-pork-production-and-h1n1/',
#   'snippet': 'A debate over the connection between large-scale concentrated animal feeding operations and the spread of the H1N1 virus is spilling into the mainstream.',
#   'lead_paragraph': 'Until now, debate over the relationship between the H1N1 influenza virus and large-scale concentrated animal feeding operations — defined by the Environmental Protection Agency as agricultural operations over a certain size “where animals are kept and raised in confined situations” — has been simmering outside the limelight.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Debate: Modern Pork Production and H1N1',
#    'kicker': 'Green',
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2009-11-09T14:25:00+0000',
#   'document_type': 'article',
#   'news_desk': '',
#   'section_name': 'Business Day',
#   'subsection_name': 'Energy & Environment ',
#   'byline': {'original': 'By Leora Broydo Vestel',
#    'person': [{'firstname': 'Leora',
#      'middlename': 'Broydo',
#      'lastname': 'Vestel',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   '_id': 'nyt://article/59328a33-f0f0-5e75-8014-6358e3042614',
#   'word_count': 556,
#   'uri': 'nyt://article/59328a33-f0f0-5e75-8014-6358e3042614'},
#  {'abstract': 'Landon Donovan tested positive for the H1N1 flu virus, known as swine flu.',
#   'web_url': 'https://goal.blogs.nytimes.com/2009/08/14/donovan-tests-positive-for-h1n1-flu-virus/',
#   'snippet': 'Landon Donovan tested positive for the H1N1 flu virus, known as swine flu.',
#   'lead_paragraph': 'A day after he played a full 90 minutes in the United States national team’s 2-1 loss to Mexico, Landon Donovan revealed he tested positive for the H1N1 flu virus, or swine flu, according to a report first published on SI.com.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Donovan Tests Positive for H1N1 Flu Virus',
#    'kicker': 'Goal',
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2009-08-14T13:51:00+0000',
#   'document_type': 'article',
#   'news_desk': '',
#   'section_name': 'Sports',
#   'subsection_name': 'Soccer',
#   'byline': {'original': 'By Jeffrey Marcus',
#    'person': [{'firstname': 'Jeffrey',
#      'middlename': None,
#      'lastname': 'Marcus',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/b715d76b-cad9-57ff-a417-b8993784fa57',
#   'word_count': 255,
#   'uri': 'nyt://article/b715d76b-cad9-57ff-a417-b8993784fa57'},
#  {'abstract': 'An extensive review shows side effects no different from those of seasonal flu vaccines, health officials reported.',
#   'web_url': 'https://www.nytimes.com/2009/12/05/health/05flu.html',
#   'snippet': 'An extensive review shows side effects no different from those of seasonal flu vaccines, health officials reported.',
#   'lead_paragraph': 'An extensive review of adverse effects from the swine flu vaccine indicates that the vaccine is safe, with side effects no different from those of seasonal flu vaccines, health officials reported on Friday. ',
#   'print_section': 'A',
#   'print_page': '13',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Review Shows Safety of H1N1 Vaccine, Officials Say',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Review Shows Safety of H1N1 Vaccine, Officials Say',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Vaccination and Immunization',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'ACCIDENTS AND SAFETY',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Centers for Disease Control and Prevention',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Frieden, Thomas R', 'rank': 4, 'major': 'N'},
#    {'name': 'subject', 'value': 'Swine Influenza', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2009-12-05T01:02:27+0000',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'Health',
#   'byline': {'original': 'By Denise Grady',
#    'person': [{'firstname': 'Denise',
#      'middlename': None,
#      'lastname': 'Grady',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/87a25745-6232-551c-8bce-7d33454faed4',
#   'word_count': 542,
#   'uri': 'nyt://article/87a25745-6232-551c-8bce-7d33454faed4'},
#  {'abstract': 'Why Americans are wrong to fear the H1N1 flu vaccine.',
#   'web_url': 'https://www.nytimes.com/2009/10/12/opinion/12offit.html',
#   'snippet': 'Why Americans are wrong to fear the H1N1 flu vaccine.',
#   'lead_paragraph': 'Philadelphia',
#   'print_section': 'A',
#   'print_page': '23',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/12/opinion/12sick190h.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2009/10/12/opinion/12sick190h.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/12/opinion/12sicklarge.jpg',
#     'height': 425,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2009/10/12/opinion/12sicklarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 425},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/12/opinion/12sicklarge.jpg',
#     'height': 425,
#     'width': 600,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/12/opinion/12sick190v.jpg',
#     'height': 134,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/10/12/opinion/12sick75.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2009/10/12/opinion/12sick75.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'}],
#   'headline': {'main': 'Nothing to Fear but the Flu Itself',
#    'kicker': 'Op-Ed Contributor',
#    'content_kicker': None,
#    'print_headline': 'Nothing to Fear but the Flu Itself',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Medicine and Health',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Food and Drug Administration',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Vaccination and Immunization',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Viruses', 'rank': 4, 'major': 'N'},
#    {'name': 'subject', 'value': 'Swine Influenza', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2009-10-12T00:05:59+0000',
#   'document_type': 'article',
#   'news_desk': 'OpEd',
#   'section_name': 'Opinion',
#   'byline': {'original': 'By Paul A. Offit',
#    'person': [{'firstname': 'Paul',
#      'middlename': 'A.',
#      'lastname': 'Offit',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Op-Ed',
#   '_id': 'nyt://article/e582954e-681a-5022-89cd-3c24bfa5f815',
#   'word_count': 695,
#   'uri': 'nyt://article/e582954e-681a-5022-89cd-3c24bfa5f815'},
#  {'abstract': '“Consenting” to anti-H1N1 efforts in Beijing.',
#   'web_url': 'https://www.nytimes.com/2009/11/29/magazine/29lives-t.html',
#   'snippet': '“Consenting” to anti-H1N1 efforts in Beijing.',
#   'lead_paragraph': ' Late in August, while our 747 circled the Beijing haze, I prepared to ply both my boys with pink, chewable Tylenol. I’d heard from friends that the capital had gone H1N1-quarantine-mad: locking up tourists in policed hotels, isolating children in hospital rooms. It was the start of our third year in China. We’d first come on my sinophile husband’s consulting visa, and happily stayed, learning Mandarin and walking the hutongs. ',
#   'print_section': 'MM',
#   'print_page': '58',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/11/29/magazine/29lives/articleInline.jpg',
#     'height': 181,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2009/11/29/magazine/29lives/thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2009/11/29/magazine/29lives/thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'}],
#   'headline': {'main': 'The China Flu Blues',
#    'kicker': 'Lives',
#    'content_kicker': None,
#    'print_headline': 'The China Flu Blues',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'glocations',
#     'value': 'China',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Medicine and Health',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Swine Influenza', 'rank': 3, 'major': 'N'}],
#   'pub_date': '2009-11-24T20:48:30+0000',
#   'document_type': 'article',
#   'news_desk': 'Magazine',
#   'section_name': 'Magazine',
#   'byline': {'original': 'By Susan Conley',
#    'person': [{'firstname': 'Susan',
#      'middlename': None,
#      'lastname': 'Conley',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/50f17e5b-69a6-5391-982b-8b00c0d70f99',
#   'word_count': 803,
#   'uri': 'nyt://article/50f17e5b-69a6-5391-982b-8b00c0d70f99'},
#  {'abstract': 'Landon Donovan tested positive for the H1N1 flu virus, known as swine flu.',
#   'web_url': 'https://goal.blogs.nytimes.com/2009/08/14/blogs/14goal-donovan-9017.html',
#   'snippet': 'Landon Donovan tested positive for the H1N1 flu virus, known as swine flu.',
#   'lead_paragraph': "A day after he played a full 90 minutes in the United States national team's 2-1 loss to Mexico, Landon Donovan revealed he tested positive for the H1N1 flu virus, or swine flu, according to a report first published on SI.com.",
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Donovan Tests Positive for H1N1 Flu Virus',
#    'kicker': 'Goal',
#    'content_kicker': None,
#    'print_headline': 'Donovan Tests Positive for H1N1 Flu Virus',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2009-08-14T13:51:00+0000',
#   'document_type': 'article',
#   'news_desk': 'None',
#   'section_name': 'Blogs',
#   'byline': {'original': 'By JEFFREY MARCUS',
#    'person': [{'firstname': 'Jeffrey',
#      'middlename': None,
#      'lastname': 'MARCUS',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Web Log',
#   '_id': 'nyt://article/5c42e4da-b122-5445-ab56-e8404982b56d',
#   'word_count': 260,
#   'uri': 'nyt://article/5c42e4da-b122-5445-ab56-e8404982b56d'},
#  {'abstract': 'The swine flu vaccine is now amply stocked, but Americans should not get blasé about the next outbreak.',
#   'web_url': 'https://www.nytimes.com/2010/04/08/opinion/08thu3.html',
#   'snippet': 'The swine flu vaccine is now amply stocked, but Americans should not get blasé about the next outbreak.',
#   'lead_paragraph': 'Just a few months ago, nervous Americans were clamoring for access to vaccines that could protect them against the swine flu. Now there is a glut of vaccine available, and American health officials are renewing their calls for more people to get vaccinated \x97 just in case the virus resurges in coming months. ',
#   'print_section': 'A',
#   'print_page': '30',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'H1N1 Vaccine, Still Available',
#    'kicker': 'Editorial',
#    'content_kicker': None,
#    'print_headline': 'H1N1 Vaccine, Still Available',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Swine Influenza',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'World Health Organization',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Vaccination and Immunization',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2010-04-08T01:42:50+0000',
#   'document_type': 'article',
#   'news_desk': 'Editorial',
#   'section_name': 'Opinion',
#   'byline': {'original': None, 'person': [], 'organization': None},
#   'type_of_material': 'Editorial',
#   '_id': 'nyt://article/babbf44b-9b50-5874-b5b1-f457b62a011b',
#   'word_count': 391,
#   'uri': 'nyt://article/babbf44b-9b50-5874-b5b1-f457b62a011b'}]

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)
    return(news)

# %%
def get_articles(date,query):
    '''
    This function accepts a year in string format (e.g.'1980')
    and a query (e.g.'Amnesty International') and it will 
    return a list of parsed articles (in dictionaries)
    for that year.
    '''
    all_articles = []
    for i in range(0,100): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
        articles = api.search(q = query,
               fq = {'source':['Reuters','AP', 'The New York Times']},
               begin_date = date + '0101',
               end_date = date + '1231',
               sort='oldest',
               page = str(i))
        articles = parse_articles(articles)
        all_articles = all_articles + articles
    return(all_articles)

# %%
get_articles("2009", "H1N1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-4bca575ba312> in <module>
# ----> 1 get_articles("2009", "H1N1")
#
# <ipython-input-42-ccc4f22d5cdc> in get_articles(date, query)
#      13                end_date = date + '1231',
#      14                sort='oldest',
# ---> 15                page = str(i))
#      16         articles = parse_articles(articles)
#      17         all_articles = all_articles + articles
#
# ~/miniconda3/lib/python3.7/site-packages/nytimesarticle.py in search(self, response_format, key, **kwargs)
#     109
#     110         url = '%s%s?%sapi-key=%s' % (
# --> 111             API_ROOT, response_format, self._options(**kwargs), key
#     112         )
#     113
#
# ~/miniconda3/lib/python3.7/site-packages/nytimesarticle.py in _options(self, **kwargs)
#      82         for k, v in kwargs.items():
#      83             if k is 'fq' and isinstance(v, dict):
# ---> 84                 v = _format_fq(v)
#      85             elif isinstance(v, list):
#      86                 v = ','.join(v)
#
# ~/miniconda3/lib/python3.7/site-packages/nytimesarticle.py in _format_fq(d)
#      65             for k,v in d.items():
#      66                 if isinstance(v, list):
# ---> 67                     d[k] = ' '.join(map(lambda x: '"' + x + '"', v))
#      68                 else:
#      69                     d[k] = '"' + v + '"'
#
# ~/miniconda3/lib/python3.7/site-packages/nytimesarticle.py in <lambda>(x)
#      65             for k,v in d.items():
#      66                 if isinstance(v, list):
# ---> 67                     d[k] = ' '.join(map(lambda x: '"' + x + '"', v))
#      68                 else:
#      69                     d[k] = '"' + v + '"'
#
# TypeError: can only concatenate str (not "bytes") to str

# %%
articles['response']['docs'][5]
# Out:
# {'abstract': 'An extensive review shows side effects no different from those of seasonal flu vaccines, health officials reported.',
#  'web_url': 'https://www.nytimes.com/2009/12/05/health/05flu.html',
#  'snippet': 'An extensive review shows side effects no different from those of seasonal flu vaccines, health officials reported.',
#  'lead_paragraph': 'An extensive review of adverse effects from the swine flu vaccine indicates that the vaccine is safe, with side effects no different from those of seasonal flu vaccines, health officials reported on Friday. ',
#  'print_section': 'A',
#  'print_page': '13',
#  'source': 'The New York Times',
#  'multimedia': [],
#  'headline': {'main': 'Review Shows Safety of H1N1 Vaccine, Officials Say',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': 'Review Shows Safety of H1N1 Vaccine, Officials Say',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject',
#    'value': 'Vaccination and Immunization',
#    'rank': 1,
#    'major': 'N'},
#   {'name': 'subject',
#    'value': 'ACCIDENTS AND SAFETY',
#    'rank': 2,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Centers for Disease Control and Prevention',
#    'rank': 3,
#    'major': 'N'},
#   {'name': 'persons', 'value': 'Frieden, Thomas R', 'rank': 4, 'major': 'N'},
#   {'name': 'subject', 'value': 'Swine Influenza', 'rank': 5, 'major': 'N'}],
#  'pub_date': '2009-12-05T01:02:27+0000',
#  'document_type': 'article',
#  'news_desk': 'National',
#  'section_name': 'Health',
#  'byline': {'original': 'By Denise Grady',
#   'person': [{'firstname': 'Denise',
#     'middlename': None,
#     'lastname': 'Grady',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'News',
#  '_id': 'nyt://article/87a25745-6232-551c-8bce-7d33454faed4',
#  'word_count': 542,
#  'uri': 'nyt://article/87a25745-6232-551c-8bce-7d33454faed4'}

# %%
url = articles['response']['docs'][2]["web_url"]
article = Article(url)
article.download()
article.parse()
article.nlp()
print(article.keywords)
print(article.summary)
# Out:
# ['measures', 'h1n1', 'child', 'local', 'monitor', 'flu', 'opinion', 'parents', 'school', 'schools', 'severe', 'abcs', 'team']
# Schools can take several measures to help keep flu from spreading: Hand-washing and coughing or sneezing into the arm or a tissue should be stressed.
# Hand-sanitizing gel dispensers should be available throughout schools for both staff members and students.
# To make sure that such measures are taken in all schools, every county should create an influenza action team run by the local health department and including parents and school administrators.
# (The team should also include local doctors and nurses, government officials and the news media.)
# Since the novel H1N1 virus infection so far appears to be about as severe as ordinary seasonal flu, parents should seek a doctor’s help if the child seems to have a severe case or is at high risk for complications.

# %%
import newspaper

# %%
paper = newspaper.build('https://edition.cnn.com/2013/01/11/health', memoize_articles=False, request_timeout=15)

# %%
len(paper.articles)
# Out:
# 0

# %%
for article in paper.articles:
    if "2013" in article.url:
        print(article.url)

# %%
article = Article("https://edition.cnn.com/2013/01/11/health/flu-dont-know/index.html")

# %%
article.download()
article.parse()
article.nlp()
print(article.keywords)
print(article.summary)
# Out:
# ['dont', 'strains', 'peak', 'vaccines', 'viruses', 'flu', 'things', 'know', 'influenza', 'season', 'seasonal', 'watch', 'watched']
# Here are three things we still don't know about the flu:When flu seasons begin and end.
# Seasonal flu activity can begin as early as October and continue to occur as late as May, according to the Seasonal flu activity can begin as early as October and continue to occur as late as May, according to the Centers for Disease Control and Prevention .
# "This is the earliest regular flu season we've had in nearly a decade, since the 2003-2004 flu season," he said.
# 03:02JUST WATCHED Your flu questions answered Replay More Videos ... MUST WATCH Your flu questions answered 00:59JUST WATCHED Saving your child's life from the flu Replay More Videos ... MUST WATCH Saving your child's life from the flu 02:10JUST WATCHED Worst flu season in a decade Replay More Videos ... MUST WATCH Worst flu season in a decade 03:19When flu cases peak.
# The CDC considers the second peak, in October, to be the peak of the 2009-2010 flu season because the April peak occurred after the flu season had ended.

# %%
from newspaper.source import Source

# %%
a = Source(url="http://cnn.com/2009/", memoize_articles=False, )

# %%
a.build()

# %%
a.categories[5].url
# Out:
# 'http://cnn.com/china'

# %%
article = a.articles[0]

# %%
for article in a.articles:
    if "2009" not in article.url:
        continue
    print(article.url)
    try:
        article.download()
        article.parse()
        
#         print("Success")
        print(article.publish_date)
    except KeyboardInterrupt:
        raise
    except:
        print("Fail")
        pass
# Out:
# https://cnnespanol.cnn.com/2020/04/03/la-economia-estadounidense-perdio-701-000-empleos-en-marzo-el-peor-reporte-desde-2009/
# 2020-04-03 00:00:00
