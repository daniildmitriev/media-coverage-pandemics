# %%
import twint
import pandas as pd
import argparse
import os
import datetime
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
df = pd.read_csv('WHO_covid.csv')

# %%
def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet



def compute_lda_model(df, number_of_topics):
    
    removed = df.tweet.apply(remove_links)
    removed = df.tweet.apply(remove_users)
    removed = df.tweet.apply(clean_tweet)
    
    vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')
    tf = vectorizer.fit_transform(removed).toarray()
    tf_feature_names = vectorizer.get_feature_names()
    

    model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)
    return model.fit(tf), tf_feature_names
    
    
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
model, features = compute_lda_model(df, 5) #5 topics

# %%
display_topics(model, features, 25) #25 words from each topic
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0            com           357.9        #covid           332.9        #covid
# 1            pic           357.9  #coronavirus           274.8             …
# 2        twitter           357.6       countri           213.9  #coronavirus
# 3   #coronavirus           192.6             ’           122.3       countri
# 4         health           178.7            we           118.2         #ncov
# 5         #covid           140.2            ’r           105.2      outbreak
# 6          emerg           123.1             ”            97.5        health
# 7           food            96.1          take            78.4       respons
# 8        protect            91.4          work            73.5         brief
# 9         suppli            82.2        togeth            72.4         peopl
# 10        provid            77.8            us            70.7          know
# 11         peopl            76.9         world            69.4          live
# 12          help            76.1        commun            67.8            ’t
# 13        person            75.0            it            64.9      research
# 14          safe            74.1           one            64.2        global
# 15          need            73.4          risk            62.6         media
# 16        intern            72.9          mani            61.6          also
# 17       healthi            70.2         share            54.0        #ebola
# 18        public            70.1          base            53.8        system
# 19             ⃣            68.6        health            53.1          work
# 20      committe            68.2       solidar            51.6             ’
# 21       product            66.6          also            49.8        measur
# 22           use            65.8             –            49.6          #drc
# 23           new            64.3          time            49.2          need
# 24          work            62.5       protect            48.8      prepared
#
#    Topic 2 weights  Topic 3 words Topic 3 weights Topic 4 words  \
# 0            318.7        twitter           866.3          case
# 1            183.9            pic           865.1  #coronavirus
# 2            166.5            com           865.1        report
# 3            156.5         health           363.9        #covid
# 4            147.7          peopl           205.6       twitter
# 5            137.8         diseas           155.9           pic
# 6            127.2           year           136.6           com
# 7            111.5       children           129.9       countri
# 8             89.2  #healthforall           117.2     transmiss
# 9             84.2           risk           107.1        situat
# 10            84.1              ’           102.8       confirm
# 11            74.4        countri            88.7           new
# 12            74.2        million            88.4        #china
# 13            71.7          women            88.4        infect
# 14            66.9        prevent            88.3          ncov
# 15            66.2           time            79.2       contact
# 16            64.3           live            78.6       patient
# 17            61.7            use            77.5            🇨🇳
# 18            61.0      treatment            74.6          test
# 19            60.6            let            68.9         death
# 20            59.0        tobacco            67.2       prevent
# 21            58.5              👉            66.7        number
# 22            58.2         cancer            66.2         sever
# 23            57.3           care            66.1   respiratori
# 24            54.1         vaccin            66.0         novel
#
#    Topic 4 weights
# 0            480.2
# 1            311.0
# 2            241.2
# 3            232.0
# 4            162.4
# 5            160.4
# 6            160.4
# 7            158.9
# 8            156.1
# 9             94.3
# 10            88.2
# 11            86.6
# 12            86.3
# 13            84.2
# 14            80.5
# 15            79.9
# 16            77.5
# 17            74.2
# 18            73.5
# 19            69.8
# 20            68.8
# 21            65.4
# 22            64.3
# 23            63.5
# 24            62.2

# %%
tf_feature_names
# Out:
# ['#beatncds',
#  '#cancer',
#  '#china',
#  '#china🇨🇳',
#  '#coronavirus',
#  '#covid',
#  '#depression',
#  '#drc',
#  '#eb',
#  '#ebola',
#  '#healthforall',
#  '#healthworkers',
#  '#hiv',
#  '#letstalk',
#  '#mentalhealth',
#  '#msc',
#  '#ncov',
#  '#roadsafety',
#  '#safehands',
#  '#supportnursesandmidwives',
#  'acceler',
#  'access',
#  'achiev',
#  'act',
#  'action',
#  'activ',
#  'address',
#  'adult',
#  'advic',
#  'affect',
#  'africa',
#  'age',
#  'alcohol',
#  'almost',
#  'alreadi',
#  'also',
#  'although',
#  'among',
#  'anim',
#  'approach',
#  'appropri',
#  'area',
#  'around',
#  'ask',
#  'assess',
#  'avail',
#  'avoid',
#  'base',
#  'becom',
#  'best',
#  'better',
#  'brief',
#  'bring',
#  'build',
#  'call',
#  'cancer',
#  'capac',
#  'care',
#  'case',
#  'caus',
#  'challeng',
#  'chang',
#  'child',
#  'children',
#  'clean',
#  'clear',
#  'clinic',
#  'close',
#  'cluster',
#  'com',
#  'come',
#  'commit',
#  'committe',
#  'common',
#  'commun',
#  'concern',
#  'condit',
#  'confirm',
#  'contact',
#  'contain',
#  'continu',
#  'contribut',
#  'control',
#  'coordin',
#  'cough',
#  'could',
#  'countri',
#  'coverag',
#  'covid',
#  'crisi',
#  'critic',
#  'current',
#  'daili',
#  'data',
#  'day',
#  'death',
#  'decis',
#  'declar',
#  'declin',
#  'detect',
#  'develop',
#  'diagnos',
#  'diagnost',
#  'die',
#  'diet',
#  'differ',
#  'disabl',
#  'diseas',
#  'distanc',
#  'don',
#  'earli',
#  'eat',
#  'econom',
#  'effect',
#  'effort',
#  'emerg',
#  'encourag',
#  'end',
#  'engag',
#  'ensur',
#  'epidem',
#  'equip',
#  'especi',
#  'essenti',
#  'estim',
#  'even',
#  'event',
#  'everi',
#  'everyon',
#  'evid',
#  'experi',
#  'expert',
#  'face',
#  'facil',
#  'fact',
#  'famili',
#  'far',
#  'fear',
#  'februari',
#  'feel',
#  'fight',
#  'find',
#  'first',
#  'follow',
#  'food',
#  'free',
#  'full',
#  'fund',
#  'futur',
#  'gener',
#  'get',
#  'give',
#  'global',
#  'go',
#  'good',
#  'govern',
#  'group',
#  'guidanc',
#  'hand',
#  'harm',
#  'health',
#  'healthi',
#  'heart',
#  'help',
#  'high',
#  'hiv',
#  'home',
#  'hospit',
#  'human',
#  'i',
#  'identifi',
#  'ill',
#  'impact',
#  'import',
#  'improv',
#  'incl',
#  'includ',
#  'incom',
#  'increas',
#  'individu',
#  'infect',
#  'inform',
#  'initi',
#  'innov',
#  'intern',
#  'invest',
#  'investig',
#  'isol',
#  'issu',
#  'it',
#  'januari',
#  'join',
#  'keep',
#  'key',
#  'kill',
#  'know',
#  'laboratori',
#  'lack',
#  'larg',
#  'last',
#  'launch',
#  'lead',
#  'leader',
#  'learn',
#  'less',
#  'let',
#  'level',
#  'life',
#  'like',
#  'limit',
#  'list',
#  'live',
#  'long',
#  'look',
#  'loss',
#  'low',
#  'made',
#  'major',
#  'make',
#  'manag',
#  'mani',
#  'mask',
#  'may',
#  'mean',
#  'measur',
#  'media',
#  'medic',
#  'medicin',
#  'meet',
#  'member',
#  'messag',
#  'middl',
#  'midwiv',
#  'million',
#  'minist',
#  'monitor',
#  'month',
#  'much',
#  'must',
#  'nation',
#  'ncov',
#  'need',
#  'new',
#  'novel',
#  'number',
#  'nurs',
#  'often',
#  'older',
#  'one',
#  'opportun',
#  'organ',
#  'other',
#  'outbreak',
#  'outsid',
#  'pandem',
#  'part',
#  'partner',
#  'past',
#  'patient',
#  'peopl',
#  'person',
#  'physic',
#  'pic',
#  'place',
#  'plan',
#  'play',
#  'polit',
#  'popul',
#  'posit',
#  'possibl',
#  'potenti',
#  'prepar',
#  'prepared',
#  'prevent',
#  'prioriti',
#  'product',
#  'progress',
#  'promot',
#  'protect',
#  'provid',
#  'public',
#  'publish',
#  'put',
#  'q',
#  'qualiti',
#  'question',
#  'reach',
#  'readi',
#  'receiv',
#  'recommend',
#  'reduc',
#  'region',
#  'regul',
#  'relat',
#  'remain',
#  'report',
#  'requir',
#  'research',
#  'resourc',
#  'respiratori',
#  'respond',
#  'respons',
#  'result',
#  'right',
#  'risk',
#  'role',
#  'safe',
#  'save',
#  'say',
#  'screen',
#  'see',
#  'seen',
#  'servic',
#  'set',
#  'sever',
#  'share',
#  'ship',
#  'show',
#  'sick',
#  'sign',
#  'sinc',
#  'situat',
#  'slow',
#  'sneez',
#  'social',
#  'societi',
#  'solidar',
#  'someon',
#  'sourc',
#  'spread',
#  'start',
#  'stay',
#  'step',
#  'still',
#  'stop',
#  'strengthen',
#  'suffer',
#  'suppli',
#  'support',
#  'surveil',
#  'suspect',
#  'symptom',
#  'system',
#  'take',
#  'taken',
#  'talk',
#  'team',
#  'test',
#  'thank',
#  'therapeut',
#  'threat',
#  'time',
#  'tobacco',
#  'today',
#  'togeth',
#  'total',
#  'trace',
#  'train',
#  'transmiss',
#  'transmit',
#  'travel',
#  'treat',
#  'treatment',
#  'twitter',
#  'two',
#  'understand',
#  'univers',
#  'us',
#  'use',
#  'vaccin',
#  'viru',
#  'vulner',
#  'wash',
#  'water',
#  'way',
#  'we',
#  'week',
#  'well',
#  'who',
#  'without',
#  'women',
#  'work',
#  'worker',
#  'world',
#  'worldwid',
#  'would',
#  'year',
#  'young',
#  '–',
#  '’',
#  '’r',
#  '’t',
#  '’v',
#  '”',
#  '…',
#  '⃣',
#  '🇨🇳',
#  '🌍',
#  '👇',
#  '👉',
#  '🚭',
#  '🧼']

# %%
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
#     Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights  \
# 0             com           227.8        #covid           201.5
# 1             pic           227.8  #coronavirus           182.8
# 2         twitter           227.7       countri           156.6
# 3            help            94.9             ”            78.6
# 4           peopl            93.8          risk            71.0
# 5          #covid            82.1             ’            67.1
# 6    #coronavirus            66.8          nurs            60.1
# 7           activ            66.3        commun            54.6
# 8          health            59.3          take            54.6
# 9         support            56.5        epidem            52.1
# 10         provid            48.1         level            45.3
# 11           safe            48.0       guidanc            43.3
# 12            may            47.8        measur            41.7
# 13         physic            43.2            us            40.0
# 14  #mentalhealth            41.8       potenti            37.9
# 15         inform            40.2     transmiss            37.9
# 16           work            39.4        differ            37.5
# 17        healthi            38.4        health            36.6
# 18         travel            38.0          mani            35.3
# 19           stay            37.1          #msc            34.6
#
#      Topic 2 words Topic 2 weights Topic 3 words Topic 3 weights  \
# 0           #covid           207.3       twitter           491.9
# 1     #coronavirus           153.8           com           490.0
# 2           health            94.7           pic           490.0
# 3          countri            83.4        infect           119.5
# 4               ’t            72.2       prevent           107.8
# 5            peopl            69.8           use            97.2
# 6          patient            64.9           new            82.3
# 7             care            55.9       tobacco            67.1
# 8             know            55.3          risk            61.1
# 9          protect            51.3        vaccin            60.6
# 10               ’            49.2             q            56.3
# 11  #healthworkers            48.8        diseas            51.2
# 12               ⃣            48.7         reduc            43.7
# 13          system            47.8         peopl            39.7
# 14             way            44.8          food            39.6
# 15           everi            43.4        effect            38.3
# 16            need            43.0       control            37.9
# 17             don            43.0     treatment            35.7
# 18          measur            42.9       protect            34.6
# 19            also            42.5             🚭            32.0
#
#    Topic 4 words Topic 4 weights Topic 5 words Topic 5 weights Topic 6 words  \
# 0           case           381.0        #covid           159.9         emerg
# 1         report           241.1  #coronavirus           129.2        health
# 2   #coronavirus           193.7             …           105.2  #coronavirus
# 3         #covid           129.9         brief            89.1          case
# 4        countri           111.5           com            83.8      outbreak
# 5        twitter            92.8           pic            83.8        intern
# 6            com            90.9       twitter            83.8     transmiss
# 7            pic            90.9          hand            71.0      committe
# 8         #china            87.5         media            66.1        public
# 9         situat            80.7           use            52.5        #ebola
# 10            🇨🇳            75.0          wash            48.1       contact
# 11         human            68.9         cough            48.1        commun
# 12        number            67.8             🧼            46.1        #covid
# 13          ncov            67.3          full            43.5           pic
# 14       confirm            66.4          sick            39.3           com
# 15         death            66.3         other            35.5       twitter
# 16     transmiss            64.7         water            35.4          isol
# 17           new            61.7       protect            34.8           new
# 18        outsid            61.1          food            34.4          #drc
# 19         novel            54.4        person            30.2          find
#
#    Topic 6 weights Topic 7 words Topic 7 weights Topic 8 words  \
# 0            140.1         peopl           143.8        #covid
# 1            130.2        diseas           118.8       countri
# 2            112.4           pic           114.2            we
# 3             98.9           com           114.2          work
# 4             94.8       twitter           114.0         #ncov
# 5             92.4          year           100.9  #coronavirus
# 6             71.4       million            89.7            ’r
# 7             68.1           let            79.8       respons
# 8             59.0        cancer            66.1        togeth
# 9             58.7          live            57.4        global
# 10            58.5      children            55.9       support
# 11            58.2        around            53.6          also
# 12            58.1          caus            51.9      research
# 13            53.8             ’            51.0          need
# 14            53.8         world            42.0        suppli
# 15            53.5         everi            41.2       protect
# 16            51.1         death            40.5       solidar
# 17            48.2           die            40.1        person
# 18            44.6          risk            39.2           #eb
# 19            42.7          lead            37.4         world
#
#    Topic 8 weights  Topic 9 words Topic 9 weights
# 0            184.9         health           388.9
# 1            157.1            com           317.1
# 2            118.1            pic           317.1
# 3            115.9        twitter           316.9
# 4            107.5  #healthforall           117.1
# 5            106.0         access            98.3
# 6            105.1         servic            86.1
# 7            101.5          women            85.9
# 8             94.1        countri            73.3
# 9             90.2              ’            54.5
# 10            76.3           need            52.4
# 11            69.9           time            51.4
# 12            68.0              …            49.7
# 13            66.9        qualiti            46.6
# 14            64.8           care            46.5
# 15            62.8       children            46.1
# 16            59.0          right            46.1
# 17            55.9          peopl            40.8
# 18            55.7        product            40.8
# 19            54.6          incom            40.1

# %%
date_time_str = '2018-06-29'
    date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%d')
date_time_obj
# Out:
# datetime.datetime(2018, 6, 29, 0, 0)

# %%
start_date = datetime.datetime(2008, 1, 1)
threshold = datetime.datetime(2008,5,1)

while start_date < threshold:
    end_date = start_date + datetime.timedelta(days = 30)
    c = twint.Config()
    c.Username = "WHO"
    c.Until = end_date.strftime("%Y-%m-%d")
    c.Since = start_date.strftime("%Y-%m-%d")
    c.Store_csv = True
    c.Output = "WHO.csv"
    twint.run.Search(c)
    
    
    start_date = end_date + datetime.timedelta(days = 1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-4791ae7047fb> in <module>
#      10     c.Store_csv = True
#      11     c.Output = "WHO.csv"
# ---> 12     twint.run.Search(c)
#      13
#      14
#
# D:\murat\Anaconda3\envs\ada\lib\site-packages\twint\run.py in Search(config, callback)
#     320     config.Profile = False
#     321     config.Profile_full = False
# --> 322     run(config, callback)
#     323     if config.Pandas_au:
#     324         storage.panda._autoget("tweet")
#
# D:\murat\Anaconda3\envs\ada\lib\site-packages\twint\run.py in run(config, callback)
#     219         raise
#     220
# --> 221     get_event_loop().run_until_complete(Twint(config).main(callback))
#     222
#     223 def Favorites(config):
#
# D:\murat\Anaconda3\envs\ada\lib\asyncio\base_events.py in run_until_complete(self, future)
#     564         future.add_done_callback(_run_until_complete_cb)
#     565         try:
# --> 566             self.run_forever()
#     567         except:
#     568             if new_task and future.done() and not future.cancelled():
#
# D:\murat\Anaconda3\envs\ada\lib\asyncio\base_events.py in run_forever(self)
#     519         self._check_closed()
#     520         if self.is_running():
# --> 521             raise RuntimeError('This event loop is already running')
#     522         if events._get_running_loop() is not None:
#     523             raise RuntimeError(
#
# RuntimeError: This event loop is already running

# %%
timestampStr = start_date.strftime("%Y-%m-%d")
# Out:
# Current Timestamp :  2010-12-31

# %%
c = twint.Config()
c.Username = "WHO"
c.Until = end_date.strftime("%Y-%m-%d")
c.Since = start_date.strftime("%Y-%m-%d")
c.Store_csv = True
c.Output = "WHO.csv"
c.Lang = "en"
#c.Translate = True
c.TranslateDest = "it"
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-f53be8c7af3e> in <module>
#       8 #c.Translate = True
#       9 c.TranslateDest = "it"
# ---> 10 twint.run.Search(c)
#
# D:\murat\Anaconda3\envs\ada\lib\site-packages\twint\run.py in Search(config, callback)
#     320     config.Profile = False
#     321     config.Profile_full = False
# --> 322     run(config, callback)
#     323     if config.Pandas_au:
#     324         storage.panda._autoget("tweet")
#
# D:\murat\Anaconda3\envs\ada\lib\site-packages\twint\run.py in run(config, callback)
#     219         raise
#     220
# --> 221     get_event_loop().run_until_complete(Twint(config).main(callback))
#     222
#     223 def Favorites(config):
#
# D:\murat\Anaconda3\envs\ada\lib\asyncio\base_events.py in run_until_complete(self, future)
#     564         future.add_done_callback(_run_until_complete_cb)
#     565         try:
# --> 566             self.run_forever()
#     567         except:
#     568             if new_task and future.done() and not future.cancelled():
#
# D:\murat\Anaconda3\envs\ada\lib\asyncio\base_events.py in run_forever(self)
#     519         self._check_closed()
#     520         if self.is_running():
# --> 521             raise RuntimeError('This event loop is already running')
#     522         if events._get_running_loop() is not None:
#     523             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# 30217923326906368 2011-01-26 11:58:09 W. Europe Daylight Time <WHO> Emergency #vaccination campaign against yellow fever outbreak in Cote d'Ivoire    http://tinyurl.com/687rjsh #globalhealth #yellowfever
# 28415915137699840 2011-01-21 12:37:36 W. Europe Daylight Time <WHO> Keep schools and places where #children gather free from #marketing of unhealthy #foods  http://tinyurl.com/65ljtp7  #globalhealth
# 27402806835027968 2011-01-18 17:31:52 W. Europe Daylight Time <WHO> See the latest trends in the uptake of #telemedicine globally  http://tinyurl.com/4676goy #globalhealth
# 26670705563144192 2011-01-16 17:02:46 W. Europe Daylight Time <WHO> Exclusive #breastfeeding for six months best for babies everywhere.  http://tinyurl.com/6bhvrjh #globalhealth
# 25636224207167488 2011-01-13 20:32:06 W. Europe Daylight Time <WHO> Theme for World No #Tobacco Day 2011: The WHO Framework Convention on Tobacco Control  http://tiny.cc/lwco6 #health #globalhealth #FCTC
# 25167532688146432 2011-01-12 13:29:42 W. Europe Daylight Time <WHO> @analuhincapie: Hope you enjoyed the seminar. Small typo: #WHO Director-General's name is Margaret Chan, not Chang :-) #health
# 24911747575971840 2011-01-11 20:33:18 W. Europe Daylight Time <WHO> If you are in #Haiti, join one of the #1yearHaiti #earthquake commemorative events. List here  http://tiny.cc/jvtzl #globalhealth #health
# 24909460187123712 2011-01-11 20:24:12 W. Europe Daylight Time <WHO> Looking back - 2010: A Year of #Health Challenges for #Haiti #globalhealth #1yearHaiti  http://tiny.cc/f6t9f
# 24851279847096320 2011-01-11 16:33:01 W. Europe Daylight Time <WHO> 1 year #Haiti: Message from Dr Mirta Roses, director of the Pan American Health Organization  http://tiny.cc/ffyaz #globalhealth #health
# 23357359812251648 2011-01-07 13:36:43 W. Europe Daylight Time <WHO> @charasmatic2gd2 We have updated our factsheet on #sickle-cell #disease. It will be posted soon #globalhealth
# 23356829228601345 2011-01-07 13:34:36 W. Europe Daylight Time <WHO> @FuckConservativ You might want to check with World Organization for #Animal #Health (#OIE)  http://tiny.cc/6bing
# 22665372549251072 2011-01-05 15:47:00 W. Europe Daylight Time <WHO> @rudycrates Indonesia is in fact part of the report #health #ehealth #globalhealth #technology
# 22664678962364416 2011-01-05 15:44:15 W. Europe Daylight Time <WHO> @zauresh_ae A new survey to be done this year, we hope #kazakhstan will be part of it #health #globalhealth #ehealth #technology
# 22662178096021504 2011-01-05 15:34:18 W. Europe Daylight Time <WHO> @zugaldia Thanks for spotting it. We have a web team who worked really hard for the new face. Hope you like it!
# 22661478892961792 2011-01-05 15:31:32 W. Europe Daylight Time <WHO> @c_hub Many thanks for your comment!

# %%
print(twint.output.panda.Tweets_df)

# %%
print(len(l))

# %%
print(x[-1])
